# %% [raw]
# ---
# title: "Quarto Basics"
# execute:
#   enabled: true
# ---

# %%
import numpy as np
x = np.atan(1) * 4
x = 3.141592
print(x)

# %% [markdown]
# The value of $\pi$ is `{python} f"{x:.4g}"`
