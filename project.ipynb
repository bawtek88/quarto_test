# %% [raw]
# ---
# title: "Quarto Basics"
# format:
#   pdf:
#     toc: true
#     number-sections: true
#     colorlinks: true
# execute:
#   enabled: true
# jupyter: python3
# ---

# %%
import numpy as np
x = np.atan(1) * 4
print(x)
# Out:
# 3.141592653589793

# %% [markdown]
# The value of $\pi$ is `{python} f"{x:.4g}"`
